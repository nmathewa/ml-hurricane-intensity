# %% [markdown]
# # Model Setup

# %% [markdown]
# ---

# %% [markdown]
# ## Overview
# This notebook is for setting up a simple CNN-LSTM model to predict event-wise hurricane intensity using the prreproceesed data from the `era5_preprocessing.ipynb` notebook.
#
# 1. **Data Preparation**: Load and preprocess the data.
# 2. **Model Definition**: Define a CNN-LSTM model.
# 3. **Model Training**: Train the model on the prepared data.
# 4. **Model Evaluation**: Evaluate the model's performance on test data.

# %% [markdown]
# ---

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import xarray as xr


from sklearn.preprocessing import MinMaxScaler


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from keras.layers import Dense, Flatten, Conv2D
from tensorflow.keras.layers import  TimeDistributed, LSTM
import visualkeras
import tensorflow as tf

# %% [markdown]
# ## Load the hurricane wise variable dataset

# %% [markdown]
# In this section,we will load the preprocessed dataset containing hurricane-wise environmental variables. This dataset is essential for training our CNN-LSTM model to predict hurricane intensity.

# %%
# load the preprocessed dataset
model_input = xr.open_dataset('/test_folder/input_predictands.nc')
model_input
# Out:
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/xarray/backends/plugins.py:109: RuntimeWarning: Engine 'cfgrib' loading failed:
# module 'cfgrib.messages' has no attribute 'DEFAULT_INDEXPATH'
#   external_backend_entrypoints = backends_dict_from_pkg(entrypoints_unique)
# <xarray.Dataset> Size: 6MB
# Dimensions:      (id: 69, lead: 80, y: 5, x: 5)
# Coordinates:
#   * id           (id) float64 552B 0.0 1.0 1.5 1.667 2.0 ... 43.0 44.0 45.0 46.0
#   * lead         (lead) int64 640B 0 6 12 18 24 30 ... 444 450 456 462 468 474
#   * y            (y) int64 40B 0 1 2 3 4
#   * x            (x) int64 40B 0 1 2 3 4
#     time         (id, lead) datetime64[ns] 44kB ...
#     level        int32 4B ...
# Data variables:
#     r            (id, lead, y, x) float32 552kB ...
#     sp           (id, lead, y, x) float32 552kB ...
#     speed_shear  (id, lead, y, x) float32 552kB ...
#     sst          (id, lead, y, x) float64 1MB ...
#     u            (id, lead, y, x) float32 552kB ...
#     v            (id, lead, y, x) float32 552kB ...
#     vo           (id, lead, y, x) float32 552kB ...
#     rand_arr     (id, lead, y, x) float64 1MB ...
#     cor_params   (id, lead, y, x) float32 552kB ...
#     target       (id, lead) float64 44kB ...

# %% [markdown]
# ### Input Data prerpocessing steps
# - Nan and padded values will be set to zero
# - Set the train and test split
# - normalize using the MinMaxScaler
# - random shuffle for generalization

# %%
# remove the nan values and set it 
model_input = model_input.fillna(0)

# selecting the predictors (X) and expanding the dimensions

X_data = model_input[['u','v','vo','speed_shear','sp','r','cor_params']].to_array(dim='variable')

print(f'Dimensions are , features: {X_data.shape[0]}, Event: {X_data.shape[1]}, time(lead): {X_data.shape[2]}, lat: {X_data.shape[3]}, lon: {X_data.shape[4]}')

X_data = X_data.transpose('id', 'lead', 'y','x','variable')

print(f'X_data dimensions are: Event: {X_data.shape[0]}, time(lead): {X_data.shape[1]}, lat: {X_data.shape[2]}, lon: {X_data.shape[3]}, features: {X_data.shape[4]}')
# Out:
# Dimensions are , features: 7, Event: 69, time(lead): 80, lat: 5, lon: 5
# X_data dimensions are: Event: 69, time(lead): 80, lat: 5, lon: 5, features: 7

# %%
# selecting the target variable (y)
Y_data = model_input['target']

# expanded the dimensions of Y_data to match the expected input shape for the model
#Y_data = np.expand_dims(Y_data, axis=-1)

print(f'Target dimensions are: Event: {Y_data.shape[0]}, time(lead): {Y_data.shape[1]}')
# Out:
# Target dimensions are: Event: 69, time(lead): 80

# %%
## 80% train and 20% test split

## random shuffled the events and split the data into training and testing sets
X_train , X_test , Y_train, Y_test = train_test_split(X_data, Y_data, test_size=0.2, random_state=1)


X_train_data = X_train.values
X_test_data = X_test.values
Y_train_data = Y_train.values
Y_test_data = Y_test.values

# %%
x_train_scaler = MinMaxScaler()
x_test_scaler = MinMaxScaler()

y_train_scaler = MinMaxScaler()
y_test_scaler = MinMaxScaler()

# %%
X_train_scaled = x_train_scaler.fit_transform(X_train_data.reshape(-1, X_train_data.shape[-1])).reshape(X_train_data.shape)
Y_train_scaled = y_train_scaler.fit_transform(Y_train_data.reshape(-1,1)).reshape(Y_train_data.shape)

X_test_scaled = x_test_scaler.fit_transform(X_test_data.reshape(-1, X_test_data.shape[-1])).reshape(X_test_data.shape)
Y_test_scaled = y_test_scaler.fit_transform(Y_test_data.reshape(-1,1)).reshape(Y_test_data.shape)

# %%
def masked_mse(y_true, y_pred):
    mask = tf.cast(tf.not_equal(y_true, 0.0), tf.float32)
    squared_error = tf.square(y_true - y_pred)
    masked_loss = tf.reduce_sum(squared_error * mask) / (tf.reduce_sum(mask) + 1e-6)
    return masked_loss

model = Sequential()
model.add(TimeDistributed(
    Conv2D(16, (3, 3), activation='relu', padding='same'),
    input_shape=(80, 5, 5, 7)
))
model.add(TimeDistributed(Flatten()))
model.add(LSTM(64, return_sequences=True))  # <--- important!
model.add(TimeDistributed(Dense(1)))

model.summary()
# Out:
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed                │ (None, 80, 5, 5, 16)   │         1,024 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_1              │ (None, 80, 400)        │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 80, 64)         │       119,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ time_distributed_2              │ (None, 80, 1)          │            65 │
# │ (TimeDistributed)               │                        │               │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 120,129 (469.25 KB)
#  Trainable params: 120,129 (469.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
visualkeras.layered_view(model,scale_xy=0.6)
# Out:
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/visualkeras/layered.py:86: UserWarning: The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.
#   warnings.warn("The legend_text_spacing_offset parameter is deprecated and will be removed in a future release.")
# <PIL.Image.Image image mode=RGBA size=166x256>

# %%
model.compile(optimizer='adam', metrics=['mae'] , loss=masked_mse)

model.fit(X_train_scaled, Y_train_scaled, epochs=100, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 4s 760ms/step - loss: 0.1143 - mae: 0.1543 - val_loss: 0.0417 - val_mae: 0.2335
# Epoch 2/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0667 - mae: 0.2166 - val_loss: 0.0952 - val_mae: 0.0950
# Epoch 3/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.1101 - mae: 0.0894 - val_loss: 0.0559 - val_mae: 0.1312
# Epoch 4/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0511 - mae: 0.1304 - val_loss: 0.0214 - val_mae: 0.2207
# Epoch 5/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0333 - mae: 0.2348 - val_loss: 0.0514 - val_mae: 0.3189
# Epoch 6/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0489 - mae: 0.3205 - val_loss: 0.0468 - val_mae: 0.3298
# Epoch 7/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0429 - mae: 0.3249 - val_loss: 0.0256 - val_mae: 0.2947
# Epoch 8/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0254 - mae: 0.2928 - val_loss: 0.0252 - val_mae: 0.2739
# Epoch 9/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0290 - mae: 0.2732 - val_loss: 0.0334 - val_mae: 0.2745
# Epoch 10/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0356 - mae: 0.2759 - val_loss: 0.0308 - val_mae: 0.2996
# Epoch 11/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0308 - mae: 0.3032 - val_loss: 0.0235 - val_mae: 0.3426
# Epoch 12/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0197 - mae: 0.3486 - val_loss: 0.0245 - val_mae: 0.3849
# Epoch 13/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0235 - mae: 0.3924 - val_loss: 0.0285 - val_mae: 0.4081
# Epoch 14/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0257 - mae: 0.4096 - val_loss: 0.0259 - val_mae: 0.3974
# Epoch 15/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0230 - mae: 0.4017 - val_loss: 0.0216 - val_mae: 0.3766
# Epoch 16/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0188 - mae: 0.3754 - val_loss: 0.0203 - val_mae: 0.3496
# Epoch 17/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0178 - mae: 0.3438 - val_loss: 0.0205 - val_mae: 0.3362
# Epoch 18/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0194 - mae: 0.3378 - val_loss: 0.0190 - val_mae: 0.3357
# Epoch 19/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0184 - mae: 0.3364 - val_loss: 0.0190 - val_mae: 0.3384
# Epoch 20/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0178 - mae: 0.3368 - val_loss: 0.0183 - val_mae: 0.3328
# Epoch 21/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0170 - mae: 0.3309 - val_loss: 0.0177 - val_mae: 0.3296
# Epoch 22/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0161 - mae: 0.3254 - val_loss: 0.0172 - val_mae: 0.3288
# Epoch 23/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0175 - mae: 0.3292 - val_loss: 0.0168 - val_mae: 0.3287
# Epoch 24/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0159 - mae: 0.3268 - val_loss: 0.0166 - val_mae: 0.3226
# Epoch 25/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0156 - mae: 0.3205 - val_loss: 0.0168 - val_mae: 0.3196
# Epoch 26/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0157 - mae: 0.3189 - val_loss: 0.0164 - val_mae: 0.3193
# Epoch 27/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0145 - mae: 0.3200 - val_loss: 0.0163 - val_mae: 0.3186
# Epoch 28/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 0.0154 - mae: 0.3188 - val_loss: 0.0167 - val_mae: 0.3230
# Epoch 29/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0145 - mae: 0.3215 - val_loss: 0.0165 - val_mae: 0.3192
# Epoch 30/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0141 - mae: 0.3167 - val_loss: 0.0166 - val_mae: 0.3153
# Epoch 31/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0155 - mae: 0.3173 - val_loss: 0.0169 - val_mae: 0.3189
# Epoch 32/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0156 - mae: 0.3213 - val_loss: 0.0171 - val_mae: 0.3250
# Epoch 33/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0138 - mae: 0.3205 - val_loss: 0.0172 - val_mae: 0.3260
# Epoch 34/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0125 - mae: 0.3245 - val_loss: 0.0172 - val_mae: 0.3287
# Epoch 35/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0142 - mae: 0.3301 - val_loss: 0.0173 - val_mae: 0.3359
# Epoch 36/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0127 - mae: 0.3354 - val_loss: 0.0173 - val_mae: 0.3429
# Epoch 37/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0135 - mae: 0.3424 - val_loss: 0.0172 - val_mae: 0.3461
# Epoch 38/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0129 - mae: 0.3458 - val_loss: 0.0173 - val_mae: 0.3462
# Epoch 39/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0134 - mae: 0.3454 - val_loss: 0.0169 - val_mae: 0.3516
# Epoch 40/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0123 - mae: 0.3487 - val_loss: 0.0165 - val_mae: 0.3577
# Epoch 41/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0121 - mae: 0.3542 - val_loss: 0.0163 - val_mae: 0.3575
# Epoch 42/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0120 - mae: 0.3548 - val_loss: 0.0160 - val_mae: 0.3512
# Epoch 43/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0113 - mae: 0.3489 - val_loss: 0.0158 - val_mae: 0.3454
# Epoch 44/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0119 - mae: 0.3417 - val_loss: 0.0157 - val_mae: 0.3332
# Epoch 45/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0123 - mae: 0.3321 - val_loss: 0.0154 - val_mae: 0.3263
# Epoch 46/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0114 - mae: 0.3228 - val_loss: 0.0151 - val_mae: 0.3181
# Epoch 47/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.0111 - mae: 0.3151 - val_loss: 0.0149 - val_mae: 0.3073
# Epoch 48/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0128 - mae: 0.3076 - val_loss: 0.0147 - val_mae: 0.2978
# Epoch 49/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0109 - mae: 0.2925 - val_loss: 0.0148 - val_mae: 0.2856
# Epoch 50/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0114 - mae: 0.2829 - val_loss: 0.0149 - val_mae: 0.2796
# Epoch 51/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.0105 - mae: 0.2759 - val_loss: 0.0143 - val_mae: 0.2891
# Epoch 52/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0104 - mae: 0.2830 - val_loss: 0.0158 - val_mae: 0.3055
# Epoch 53/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0121 - mae: 0.3023 - val_loss: 0.0159 - val_mae: 0.3079
# Epoch 54/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0117 - mae: 0.3040 - val_loss: 0.0150 - val_mae: 0.2922
# Epoch 55/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0109 - mae: 0.2886 - val_loss: 0.0169 - val_mae: 0.2813
# Epoch 56/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0112 - mae: 0.2766 - val_loss: 0.0162 - val_mae: 0.2854
# Epoch 57/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0104 - mae: 0.2821 - val_loss: 0.0148 - val_mae: 0.2994
# Epoch 58/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0106 - mae: 0.2971 - val_loss: 0.0148 - val_mae: 0.2987
# Epoch 59/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0102 - mae: 0.2922 - val_loss: 0.0146 - val_mae: 0.2769
# Epoch 60/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0099 - mae: 0.2706 - val_loss: 0.0148 - val_mae: 0.2658
# Epoch 61/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0095 - mae: 0.2598 - val_loss: 0.0141 - val_mae: 0.2694
# Epoch 62/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0095 - mae: 0.2628 - val_loss: 0.0143 - val_mae: 0.2759
# Epoch 63/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0101 - mae: 0.2693 - val_loss: 0.0141 - val_mae: 0.2699
# Epoch 64/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0091 - mae: 0.2632 - val_loss: 0.0149 - val_mae: 0.2663
# Epoch 65/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0093 - mae: 0.2613 - val_loss: 0.0143 - val_mae: 0.2723
# Epoch 66/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0099 - mae: 0.2712 - val_loss: 0.0141 - val_mae: 0.2781
# Epoch 67/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0090 - mae: 0.2729 - val_loss: 0.0140 - val_mae: 0.2685
# Epoch 68/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0086 - mae: 0.2641 - val_loss: 0.0139 - val_mae: 0.2576
# Epoch 69/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0086 - mae: 0.2513 - val_loss: 0.0136 - val_mae: 0.2535
# Epoch 70/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0083 - mae: 0.2482 - val_loss: 0.0135 - val_mae: 0.2469
# Epoch 71/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0084 - mae: 0.2399 - val_loss: 0.0134 - val_mae: 0.2460
# Epoch 72/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0088 - mae: 0.2400 - val_loss: 0.0133 - val_mae: 0.2456
# Epoch 73/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0083 - mae: 0.2362 - val_loss: 0.0136 - val_mae: 0.2397
# Epoch 74/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0080 - mae: 0.2310 - val_loss: 0.0135 - val_mae: 0.2427
# Epoch 75/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0081 - mae: 0.2346 - val_loss: 0.0132 - val_mae: 0.2531
# Epoch 76/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0082 - mae: 0.2490 - val_loss: 0.0133 - val_mae: 0.2541
# Epoch 77/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - loss: 0.0084 - mae: 0.2493 - val_loss: 0.0142 - val_mae: 0.2457
# Epoch 78/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.0083 - mae: 0.2390 - val_loss: 0.0142 - val_mae: 0.2432
# Epoch 79/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0078 - mae: 0.2366 - val_loss: 0.0136 - val_mae: 0.2520
# Epoch 80/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0076 - mae: 0.2439 - val_loss: 0.0136 - val_mae: 0.2436
# Epoch 81/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0077 - mae: 0.2356 - val_loss: 0.0135 - val_mae: 0.2432
# Epoch 82/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0074 - mae: 0.2357 - val_loss: 0.0133 - val_mae: 0.2509
# Epoch 83/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.0078 - mae: 0.2418 - val_loss: 0.0132 - val_mae: 0.2406
# Epoch 84/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 0.0068 - mae: 0.2342 - val_loss: 0.0136 - val_mae: 0.2295
# Epoch 85/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.0077 - mae: 0.2225 - val_loss: 0.0136 - val_mae: 0.2268
# Epoch 86/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.0073 - mae: 0.2186 - val_loss: 0.0134 - val_mae: 0.2279
# Epoch 87/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0069 - mae: 0.2211 - val_loss: 0.0134 - val_mae: 0.2304
# Epoch 88/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0077 - mae: 0.2243 - val_loss: 0.0136 - val_mae: 0.2246
# Epoch 89/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0067 - mae: 0.2146 - val_loss: 0.0149 - val_mae: 0.2195
# Epoch 90/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0070 - mae: 0.2133 - val_loss: 0.0137 - val_mae: 0.2351
# Epoch 91/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0061 - mae: 0.2314 - val_loss: 0.0135 - val_mae: 0.2561
# Epoch 92/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0071 - mae: 0.2508 - val_loss: 0.0137 - val_mae: 0.2433
# Epoch 93/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0072 - mae: 0.2400 - val_loss: 0.0146 - val_mae: 0.2377
# Epoch 94/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0066 - mae: 0.2302 - val_loss: 0.0134 - val_mae: 0.2455
# Epoch 95/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0063 - mae: 0.2393 - val_loss: 0.0134 - val_mae: 0.2482
# Epoch 96/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0060 - mae: 0.2427 - val_loss: 0.0142 - val_mae: 0.2357
# Epoch 97/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0058 - mae: 0.2267 - val_loss: 0.0140 - val_mae: 0.2399
# Epoch 98/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0063 - mae: 0.2344 - val_loss: 0.0139 - val_mae: 0.2534
# Epoch 99/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0057 - mae: 0.2463 - val_loss: 0.0141 - val_mae: 0.2471
# Epoch 100/100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.0056 - mae: 0.2386 - val_loss: 0.0144 - val_mae: 0.2447

# %%
predict_x = model.predict(X_test_scaled)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 700ms/step

# %%
def invert_add_meta(data,scalar,xr_data):
    data = scalar.inverse_transform(data.reshape(-1 ,1)).reshape(xr_data.shape)
    added_meta = xr.DataArray(data, coords=xr_data.coords, dims=xr_data.dims)
    return added_meta

predicted_wind_speed = invert_add_meta(predict_x, y_test_scaler, Y_test)

observed_wind_speeds = Y_test

final_dset = predicted_wind_speed.to_dataset(name='predicted_wind_speed')
final_dset['observed_wind_speed'] = observed_wind_speeds
                                                    
final_dft = final_dset.to_dataframe().reset_index()

# set 0.0 as nan in observed_wind_speed
final_dft['observed_wind_speed'] = final_dft['observed_wind_speed'].replace(0.0, np.nan)

# whenever the predicted_wind_speed is nan, sdrop the entire row

final_dft = final_dft.dropna(how='any',axis=0)

final_pivot_col = final_dft.drop(columns=['time','level'])

# %%
final_pivot_col
# Out:
#         id  lead  predicted_wind_speed  observed_wind_speed
# 0     41.0     0             21.292175                 46.0
# 1     41.0     6             32.118565                 51.0
# 2     41.0    12             38.362511                 56.0
# 3     41.0    18             41.757359                 61.0
# 4     41.0    24             41.051842                 65.0
# ...    ...   ...                   ...                  ...
# 1064  35.0   144             23.910711                 58.5
# 1065  35.0   150             26.247749                 53.5
# 1066  35.0   156             28.092051                 48.5
# 1067  35.0   162             26.749924                 46.0
# 1068  35.0   168             34.784657                 51.0
#
# [306 rows x 4 columns]

# %%
import seaborn as sbs 

import seaborn as sns
import matplotlib.pyplot as plt

# Define two different palettes
palette1 = sns.dark_palette("Red", reverse=True, as_cmap=True)           # for predicted
palette2 = sns.dark_palette("Blue", reverse=True, as_cmap=True)            # for observed

fig,ax = plt.subplots(figsize=(12, 6))
# First lineplot (predicted) with palette1
sns.lineplot(
    data=final_pivot_col,
    x='lead',
    y='predicted_wind_speed',
    color='red',
    style='id',
    markers=True,
    dashes=False,
    palette=palette1,
    legend='brief'
,ax=ax)

# Second lineplot (observed) with palette2
sns.lineplot(
    data=final_pivot_col,
    x='lead',
    y='observed_wind_speed',
    color='blue',
    style='id',
    markers=True,
    dashes=False,
    palette=palette2,
    legend='brief'
,ax=ax)
plt.legend('')



# add H to the end of xticks
xticks = ax.get_xticks()
ax.set_xticks(xticks)
ax.set_xticklabels([f'{int(tick)}H' for tick in xticks])
ax.set_xlim(0, 500)


ax.set_xlabel('Lead (Hours)',fontsize=15)
ax.set_title('Predicted (Reds) vs Observed Wind Speed (Blues)',fontsize=18)

ax.set_ylabel('Wind Speed (m/s)',fontsize=15)
#sbs.lineplot(data=final_pivot_col, x='lead', y='observed_wind_speed', hue='id', style='id', markers=True, dashes=False)
# Out:
# /var/folders/bt/kswp83jx5mj4bn1bjkh9g4rsg_b7ks/T/ipykernel_1888/3583567803.py:12: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /var/folders/bt/kswp83jx5mj4bn1bjkh9g4rsg_b7ks/T/ipykernel_1888/3583567803.py:25: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.lineplot(
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /Users/nalex2023/miniconda3/envs/nma/lib/python3.12/site-packages/seaborn/_base.py:948: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# Text(0, 0.5, 'Wind Speed (m/s)')
